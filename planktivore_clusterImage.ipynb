# %%
import clustimage
import os
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
import glob

import matplotlib.pyplot as plt
from skimage import data, color
from skimage.transform import rescale, resize

from PIL import Image
import numpy as np
# Out:
# [datazets] >WARNING> Matplotlib created a temporary cache directory at /tmp/matplotlib-4jz6pi4l because the default path (/u/pdaniel/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# __Create cluster object and load images__

# %%
fnames = sorted(glob.glob("./test_data/pngs/*.png"))
cl = clustimage.Clustimage(method='pca')
results = cl.fit_transform(fnames[:10000])
# Out:
# [clustimage] >INFO> Cleaning previous fitted model results
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 10000/10000 [00:21<00:00, 466.22it/s]
# [clustimage] >INFO> Extracting features using method: [pca]
# [clustimage] >INFO> Extracted features using [pca]: samples=10000, features=126
# [clustimage] >INFO> Compute [tsne] embedding
# [clustimage] >INFO> Cluster evaluation using the [high] feature space of the [pca] features.
# [clustimage] >INFO> Saving data in memory.
# [clustimage] >INFO> Fit with method=[agglomerative], metric=[euclidean], linkage=[ward]
# [clustimage] >INFO> Evaluate using silhouette.
# [clusteval] >INFO: 100%|██████████| 22/22 [00:23<00:00,  1.05s/it]
# [clustimage] >INFO> Compute dendrogram threshold.
# [clustimage] >INFO> Optimal number clusters detected: [7].
# [clustimage] >INFO> Fin.
# [clustimage] >INFO> Updating cluster-labels and cluster-model based on the (10000, 126) feature-space.

# %%
# Evaluate plot
cl.clusteval.plot()
cl.scatter(dotsize=20, img_mean=False, plt_all=False)
# Change the clustering evaluation approach, metric, minimum expected nr. of clusters etc.
# labels = cl.cluster(min_clust=10, max_clust=30)

# # Evaluate plot
# cl.clusteval.plot()
# cl.scatter(dotsize=50, img_mean=False)

# # If you want to cluster on the low-dimensional space.
# labels = cl.cluster(min_clust=10, max_clust=50, cluster_space='low', cluster='dbscan')
# cl.scatter(dotsize=50, img_mean=False)
# Out:
# [clustimage] >INFO> Add transparency to RGB colors (last column)
# [clustimage] >INFO> Add transparency to RGB colors (last column)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Evaluate plot
#       2 cl.clusteval.plot()
# ----> 3 cl.scatter(dotsize=20, img_mean=False, plt_all=False,args_scatter={"zorder":0})
#       4 # Change the clustering evaluation approach, metric, minimum expected nr. of clusters etc.
#       5 # labels = cl.cluster(min_clust=10, max_clust=30)
#       6
#    (...)
#      12 # labels = cl.cluster(min_clust=10, max_clust=50, cluster_space='low', cluster='dbscan')
#      13 # cl.scatter(dotsize=50, img_mean=False)
#
# File ~/.local/lib/python3.8/site-packages/clustimage/clustimage.py:1731, in Clustimage.scatter(self, dotsize, legend, zoom, img_mean, text, plt_all, density, figsize, ax, args_scatter)
#    1724 args_scatter = {**default_scatter, **args_scatter}
#    1726 # Set logger to warning-error only
#    1727 # verbose = logger.getEffectiveLevel()
#    1728 # set_logger(verbose=40)
#    1729
#    1730 # Scatter
# -> 1731 fig, ax = scatterd(self.results['xycoord'][:, 0], self.results['xycoord'][:, 1], labels=labels, ax=ax, **args_scatter, verbose=get_logger())
#    1733 if hasattr(self, 'results_unique'):
#    1734     if img_mean:
#
# TypeError: scatterd() got an unexpected keyword argument 'zorder'

# %% [markdown]
# ## Feature Extraction ##

# %%
Xfeat = cl.extract_feat(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Xfeat = cl.extract_feat(X)
#
# NameError: name 'cl' is not defined

# %% [markdown]
# ## Preprocessing Images ##
# - GreyScale
# - Resizing into 128 x 128

# %%
# X = cl.import_data("./test_data/pngs")
pathnames=X['pathnames']
# img = cl.imread(pathnames[0],)
# img = Image.open(pathnames[0])

# grayimage = color.rgb2gray(img)
# image_rescaled = rescale(grayimage, 2.0, anti_aliasing=False,)
# image_resized = resize(grayimage, (128,128))


# # img = clustimage.imresize(img=img_org,dim=(128, 128))
# # img = clustimage.imscale(img)

# image_rescaled.shape
